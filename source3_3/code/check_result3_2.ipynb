# %%
import pandas as pd

# %%
import japanize_matplotlib
import matplotlib.pyplot as plt
# warning表示off
import warnings
warnings.simplefilter('ignore')

# デフォルトフォントサイズ変更
plt.rcParams['font.size'] = 10

# デフォルトグラフサイズ変更
plt.rcParams['figure.figsize'] = (16,10)

# デフォルトで方眼表示ON
plt.rcParams['axes.grid'] = True

# %%
df_list = []
for i in range(5, 21):
    df = pd.read_csv('../../../../sample_data/data/result/threshold_2000_epoch_50_w/threshold_2000_epoch_50_weighted_random_camel_'+str(i)+'.csv')
    df_list.append(df)

# %%
tmp_df =  df_list[9][df_list[9]['score_type'] == 'auc_score']
tmp_df
columns_list = tmp_df.columns.to_list()[4:]
columns_list[:0] = ['num_kf']
tmp_df = tmp_df[columns_list]
tmp_df = tmp_df.set_index('num_kf')
tmp_df

tmp_df.T.plot(xticks=range(len(columns_list[1:])))
plt.title('文脈行５における交差検証ごとのAUC推移')
plt.xlabel('epoch')
plt.ylabel('AUC')
# Out:
# Text(0, 0.5, 'AUC')

# %%
df_list2 = []
for df in df_list:
    df_list2.append(df[df['score_type'] == 'auc_score'])

con_df = pd.DataFrame()
columns_list = df_list2[0].columns.to_list()[4:]
columns_list[:0] = ['filename']
for df in df_list2:
    con_df= pd.concat([con_df, df[columns_list].groupby(['filename']).mean()], axis=0)

con_df.T.plot(xticks=range(len(columns_list))).legend(bbox_to_anchor=(1.2, 1), loc='upper right')
plt.title('文脈行５ごとの交差検証のAUC平均推移')
plt.xlabel('epoch')
plt.ylabel('AUC')
print(con_df)
separate_5_df = con_df[::5]
separate_5_df.T.plot(xticks=range(len(columns_list)))
# Out:
#                                        1         2         3         4  \
# filename
# txt_vec_and_label_camel_5.csv   0.764936  0.769711  0.771497  0.772621
# txt_vec_and_label_camel_6.csv   0.765208  0.769834  0.770944  0.772493
# txt_vec_and_label_camel_7.csv   0.765242  0.769611  0.771409  0.772152
# txt_vec_and_label_camel_8.csv   0.766378  0.770458  0.771897  0.773037
# txt_vec_and_label_camel_9.csv   0.766713  0.770587  0.772320  0.773859
# txt_vec_and_label_camel_10.csv  0.765419  0.769605  0.771412  0.773117
# txt_vec_and_label_camel_11.csv  0.765419  0.769605  0.771412  0.773117
# txt_vec_and_label_camel_12.csv  0.765599  0.769912  0.771835  0.772968
# txt_vec_and_label_camel_13.csv  0.764476  0.767906  0.770130  0.771777
# txt_vec_and_label_camel_14.csv  0.764928  0.768248  0.770059  0.771437
# txt_vec_and_label_camel_15.csv  0.765510  0.768931  0.770371  0.771749
# txt_vec_and_label_camel_16.csv  0.765698  0.768790  0.770442  0.771870
# txt_vec_and_label_camel_17.csv  0.765336  0.767723  0.769134  0.770456
# txt_vec_and_label_camel_18.csv  0.764911  0.768198  0.769536  0.770498
# txt_vec_and_label_camel_19.csv  0.763947  0.766774  0.768572  0.770258
# txt_vec_and_label_camel_20.csv  0.764688  0.767903  0.769404  0.770528
#
#                                        5         6         7         8  \
# filename
# txt_vec_and_label_camel_5.csv   0.774386  0.776009  0.777493  0.779441
# txt_vec_and_label_camel_6.csv   0.774015  0.775315  0.777144  0.778855
# txt_vec_and_label_camel_7.csv   0.773049  0.774471  0.776422  0.778313
# txt_vec_and_label_camel_8.csv   0.774797  0.775904  0.777360  0.779236
# txt_vec_and_label_camel_9.csv   0.775350  0.776897  0.778434  0.780218
# txt_vec_and_label_camel_10.csv  0.774450  0.775788  0.776742  0.779029
# txt_vec_and_label_camel_11.csv  0.774450  0.775788  0.776742  0.779029
# txt_vec_and_label_camel_12.csv  0.774407  0.775639  0.777094  0.778988
# txt_vec_and_label_camel_13.csv  0.772990  0.774396  0.775861  0.778045
# txt_vec_and_label_camel_14.csv  0.772818  0.774043  0.775653  0.777548
# txt_vec_and_label_camel_15.csv  0.773177  0.774913  0.776539  0.778251
# txt_vec_and_label_camel_16.csv  0.773006  0.774133  0.775273  0.777329
# txt_vec_and_label_camel_17.csv  0.771883  0.773236  0.774718  0.776878
# txt_vec_and_label_camel_18.csv  0.771761  0.772972  0.774397  0.776789
# txt_vec_and_label_camel_19.csv  0.771415  0.772533  0.773547  0.776073
# txt_vec_and_label_camel_20.csv  0.771426  0.772783  0.774082  0.776223
#
#                                        9        10  ...        41        42  \
# filename                                            ...
# txt_vec_and_label_camel_5.csv   0.780742  0.782425  ...  0.800031  0.800603
# txt_vec_and_label_camel_6.csv   0.780294  0.782314  ...  0.798849  0.799039
# txt_vec_and_label_camel_7.csv   0.779643  0.781477  ...  0.799645  0.799482
# txt_vec_and_label_camel_8.csv   0.780656  0.782336  ...  0.800830  0.800752
# txt_vec_and_label_camel_9.csv   0.781716  0.783269  ...  0.800730  0.800935
# txt_vec_and_label_camel_10.csv  0.780575  0.782608  ...  0.801479  0.801516
# txt_vec_and_label_camel_11.csv  0.780575  0.782608  ...  0.801479  0.801516
# txt_vec_and_label_camel_12.csv  0.780572  0.782433  ...  0.800413  0.800512
# txt_vec_and_label_camel_13.csv  0.779719  0.781349  ...  0.800166  0.800525
# txt_vec_and_label_camel_14.csv  0.779180  0.780942  ...  0.799977  0.800233
# txt_vec_and_label_camel_15.csv  0.780089  0.781624  ...  0.801027  0.801043
# txt_vec_and_label_camel_16.csv  0.779321  0.781132  ...  0.800134  0.800309
# txt_vec_and_label_camel_17.csv  0.778542  0.780417  ...  0.798673  0.798860
# txt_vec_and_label_camel_18.csv  0.778261  0.780096  ...  0.799718  0.799837
# txt_vec_and_label_camel_19.csv  0.777671  0.779429  ...  0.800286  0.800580
# txt_vec_and_label_camel_20.csv  0.777931  0.780014  ...  0.798788  0.798855
#
#                                       43        44        45        46  \
# filename
# txt_vec_and_label_camel_5.csv   0.800457  0.800653  0.800868  0.800808
# txt_vec_and_label_camel_6.csv   0.799232  0.799263  0.799303  0.799399
# txt_vec_and_label_camel_7.csv   0.799964  0.799831  0.799824  0.800224
# txt_vec_and_label_camel_8.csv   0.801185  0.801119  0.801180  0.801328
# txt_vec_and_label_camel_9.csv   0.801080  0.800922  0.800842  0.801085
# txt_vec_and_label_camel_10.csv  0.801514  0.801578  0.801676  0.801520
# txt_vec_and_label_camel_11.csv  0.801514  0.801578  0.801676  0.801520
# txt_vec_and_label_camel_12.csv  0.800256  0.800386  0.800683  0.800856
# txt_vec_and_label_camel_13.csv  0.800412  0.800448  0.800454  0.800656
# txt_vec_and_label_camel_14.csv  0.799967  0.799846  0.799842  0.800141
# txt_vec_and_label_camel_15.csv  0.801002  0.800960  0.800990  0.801286
# txt_vec_and_label_camel_16.csv  0.800423  0.800717  0.800824  0.801073
# txt_vec_and_label_camel_17.csv  0.798997  0.799086  0.799212  0.799400
# txt_vec_and_label_camel_18.csv  0.800295  0.800604  0.800614  0.800740
# txt_vec_and_label_camel_19.csv  0.800731  0.800582  0.800689  0.800909
# txt_vec_and_label_camel_20.csv  0.799144  0.799245  0.799287  0.799507
#
#                                       47        48        49        50
# filename
# txt_vec_and_label_camel_5.csv   0.800840  0.800603  0.800662  0.800998
# txt_vec_and_label_camel_6.csv   0.799152  0.799172  0.799663  0.799176
# txt_vec_and_label_camel_7.csv   0.799953  0.800035  0.800171  0.800100
# txt_vec_and_label_camel_8.csv   0.801088  0.801574  0.801735  0.801999
# txt_vec_and_label_camel_9.csv   0.800861  0.801139  0.801439  0.801233
# txt_vec_and_label_camel_10.csv  0.801445  0.801585  0.802003  0.802102
# txt_vec_and_label_camel_11.csv  0.801445  0.801585  0.802003  0.802102
# txt_vec_and_label_camel_12.csv  0.800640  0.800953  0.801302  0.801070
# txt_vec_and_label_camel_13.csv  0.800499  0.800622  0.800757  0.800768
# txt_vec_and_label_camel_14.csv  0.800175  0.800619  0.800949  0.800582
# txt_vec_and_label_camel_15.csv  0.801235  0.801474  0.801804  0.801981
# txt_vec_and_label_camel_16.csv  0.800800  0.801377  0.801670  0.801572
# txt_vec_and_label_camel_17.csv  0.799323  0.799706  0.799696  0.799675
# txt_vec_and_label_camel_18.csv  0.800486  0.800763  0.801130  0.800843
# txt_vec_and_label_camel_19.csv  0.800774  0.801010  0.801254  0.800867
# txt_vec_and_label_camel_20.csv  0.799295  0.799650  0.800019  0.799889
#
# [16 rows x 50 columns]
# <Axes: >

# %%
tem_df = con_df.reset_index()
columns_list2 = tem_df.columns.to_list()
tem_df = tem_df[columns_list2]
tem_df['id'] = [i for i in range(5,21)]
tem_df = tem_df.set_index('id')
tem_df = tem_df.drop('filename', axis='columns')
tem_df.plot().legend(bbox_to_anchor=(1.1, 1),loc='upper right')
plt.title('文脈行0～70におけるepochごとのAUC推移')
plt.xlabel('文脈行')
plt.ylabel('AUC')
# Out:
# Text(0, 0.5, 'AUC')

# %%
train_loss_df_list = []
for df in df_list:
    train_loss_df_list.append(df[df['score_type'] == 'train_loss'])
    
train_loss_con_df = pd.DataFrame()
columns_list = train_loss_df_list[0].columns.to_list()[4:]
columns_list[:0] = ['filename']
for df in train_loss_df_list:
    train_loss_con_df= pd.concat([train_loss_con_df, df[columns_list].groupby(['filename']).mean()], axis=0)

train_loss_con_df.T.plot(xticks=range(len(columns_list))).legend(bbox_to_anchor=(1.2, 1), loc='upper right')
plt.title('文脈行0～70における訓練データの損失')
plt.xlabel('epoch')
plt.ylabel('loss')
separate_5_train_loss_df = train_loss_con_df[::2]
separate_5_train_loss_df.T.plot(xticks=range(len(columns_list)))
# Out:
# <Axes: >

# %%
test_loss_df_list = []
for df in df_list:
    test_loss_df_list.append(df[df['score_type'] == 'test_loss'])
    
test_loss_con_df = pd.DataFrame()
columns_list = test_loss_df_list[0].columns.to_list()[4:]
columns_list[:0] = ['filename']
for df in test_loss_df_list:
    test_loss_con_df= pd.concat([test_loss_con_df, df[columns_list].groupby(['filename']).mean()], axis=0)
# print(test_loss_con_df)
test_loss_con_df.T.plot(xticks=range(len(columns_list))).legend(bbox_to_anchor=(1.2, 1), loc='upper right')
plt.title('文脈行0～70におけるテストデータの損失')
plt.xlabel('epoch')
plt.ylabel('loss')
separate_5_test_loss_df = test_loss_con_df[::2]
separate_5_test_loss_df.T.plot(xticks=range(len(columns_list)))
# Out:
# <Axes: >

# %%
train_acc_df_list = []
for df in df_list:
    train_acc_df_list.append(df[df['score_type'] == 'train_acc'])
    
train_acc_con_df = pd.DataFrame()
columns_list = train_acc_df_list[0].columns.to_list()[4:]
columns_list[:0] = ['filename']
for df in train_acc_df_list:
    train_acc_con_df= pd.concat([train_acc_con_df, df[columns_list].groupby(['filename']).mean()], axis=0)

train_acc_con_df.T.plot(xticks=range(len(columns_list))).legend(bbox_to_anchor=(1.2, 1), loc='upper right')
plt.title('文脈行0～70における訓練データの精度')
plt.xlabel('epoch')
plt.ylabel('accuracy')
separate_5_train_acc_df = train_acc_con_df[::2]
separate_5_train_acc_df.T.plot(xticks=range(len(columns_list)))
# Out:
# <Axes: >

# %%
test_acc_df_list = []
for df in df_list:
    test_acc_df_list.append(df[df['score_type'] == 'test_acc'])
    
test_acc_con_df = pd.DataFrame()
columns_list = test_acc_df_list[0].columns.to_list()[4:]
columns_list[:0] = ['filename']
for df in test_acc_df_list:
    test_acc_con_df= pd.concat([test_acc_con_df, df[columns_list].groupby(['filename']).mean()], axis=0)

test_acc_con_df.T.plot(xticks=range(len(columns_list))).legend(bbox_to_anchor=(1.2, 1), loc='upper right')
plt.title('文脈行0～70におけるテストデータの精度')
plt.xlabel('epoch')
plt.ylabel('accuracy')
separate_5_test_acc_df = test_acc_con_df[::5]
separate_5_test_acc_df.T.plot(xticks=range(len(columns_list)))
# Out:
# <Axes: >
