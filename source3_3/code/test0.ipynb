# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dic = {}
cnt = 0
with open('../../../../sample_data/data/camel_on_spiral/snippet_camel_0.txt') as f:
    while True:
        line = f.readline()
        if line == '':
            break
        tmp = line.split('\t')
        if tmp[1].strip() != '':
            dic[tmp[0]] = len(tmp[1:])

id_list = []
id2_list = []
for key in dic.keys():
    tmp = key.split('-')
    id_list.append(int(tmp[0]))
    id2_list.append(int(tmp[1]))
    
length_df = pd.DataFrame(
    data= {'id':id_list,
           'id2':id2_list,
           'snippet_length':dic.values()
           }
)

# %%
hexsha_df = pd.read_csv('../../../../sample_data/data/camel_on_spiral/hexsha_filename_camel.txt',
                        header=None,
                        names=["id","commit_hash", "before_filename", "after_filename","change_type"]
                        )

# %%
df = pd.merge(length_df, hexsha_df, on='id', how='left')

# %%
df2 = df[['id','change_type','snippet_length']].groupby(['id','change_type'], as_index=False).sum()

# %%
bins = [0, 100, 1000, 10000, 50000]
labels = ['0-100', '100-1000', '1000-10000', '10000-50000']  # 各範囲のラベル

df2['snippet_length_range'] = pd.cut(df2['snippet_length'], bins=bins, labels=labels)

# 範囲ごとのchange_typeの数を計算
change_type_counts = df2.groupby(['snippet_length_range', 'change_type']).size().unstack()

change_type_counts.plot(kind='bar', stacked=True)

plt.xlabel('Snippet Length Range')
plt.ylabel('Count')
plt.title('Change Type Count by Snippet Length Range')
plt.legend(title='Change Type')

plt.show()

# %%
target_ratio = 0.9

sorted_df = df2.sort_values('snippet_length')

cumulative_sum = sorted_df['snippet_length'].cumsum()
cumulative_ratio = cumulative_sum / cumulative_sum.max()

threshold_value = sorted_df.loc[cumulative_ratio >= target_ratio, 'snippet_length'].iloc[0]

print(threshold_value)
# Out:
# 2744

# %%
bins = [0, 100, 1000, 10000, 50000]
labels = ['0-100', '100-1000', '1000-10000', '10000-50000']  # 各範囲のラベル
df['snippet_length_range'] = pd.cut(df['snippet_length'], bins=bins, labels=labels)

# 範囲ごとのchange_typeの数を計算
change_type_counts = df.groupby(['snippet_length_range', 'change_type']).size().unstack()

change_type_counts.plot(kind='bar', stacked=True)

plt.xlabel('Snippet Length Range')
plt.ylabel('Count')
plt.title('Change Type Count by Snippet Length Range')
plt.legend(title='Change Type')

plt.show()

# %%
target_ratio = 0.9

sorted_df = df.sort_values('snippet_length')

cumulative_sum = sorted_df['snippet_length'].cumsum()
cumulative_ratio = cumulative_sum / cumulative_sum.max()

threshold_value = sorted_df.loc[cumulative_ratio >= target_ratio, 'snippet_length'].iloc[0]

print(threshold_value)
# Out:
# 2609

# %%
sorted_df
# Out:
#             id  id2  snippet_length                               commit_hash  \
# 250262   67069    2               1  7e65a14d0fb2e49282bbf51ebe463c6fff38073d
# 240268   64667    3               1  e696c601329d695a82673227b28ab134644bf52c
# 240266   64667    1               1  e696c601329d695a82673227b28ab134644bf52c
# 240261   64666    9               1  e696c601329d695a82673227b28ab134644bf52c
# 445351  114958   10               1  1ca43e4131f6bad5b39e9fa5b0bb0db4d357e2c2
# ...        ...  ...             ...                                       ...
# 518098  125862    1           23081  40685296333d69402111067c1a1a9b3f99a6661f
# 592150  155193    1           28877  d1099089c4af691f649080693786101d9b4c13dd
# 412710  106993    7           31793  e1cfeb5a55200350771c88c93e65720990131610
# 422919  109979    1           32689  c8d2aad1685568ac8cdc59e9e956914435fa9535
# 489334  119760    1           49908  2a0a9e6656bac7a82e6594a5a12f889834d6f2b6
#
#                                           before_filename  \
# 250262  components/camel-aws/src/test/java/org/apache/...
# 240268  components/camel-jpa/src/test/java/org/apache/...
# 240266  components/camel-jpa/src/test/java/org/apache/...
# 240261  components/camel-jpa/src/test/java/org/apache/...
# 445351  components/camel-reactive-streams/src/main/jav...
# ...                                                   ...
# 518098  components/camel-hl7/src/main/java/org/apache/...
# 592150  camel-core/src/main/java/org/apache/camel/impl...
# 412710  components/camel-salesforce/camel-salesforce-c...
# 422919  connectors/examples/salesforce-upsert-contact-...
# 489334  components/camel-thrift/src/test/java/org/apac...
#
#                                            after_filename change_type  \
# 250262  components/camel-aws/src/test/java/org/apache/...           M
# 240268  components/camel-jpa/src/test/java/org/apache/...           M
# 240266  components/camel-jpa/src/test/java/org/apache/...           M
# 240261  components/camel-jpa/src/test/java/org/apache/...           M
# 445351  components/camel-reactive-streams/src/main/jav...           M
# ...                                                   ...         ...
# 518098  components/camel-hl7/src/main/java/org/apache/...           A
# 592150  camel-core/src/main/java/org/apache/camel/impl...           A
# 412710  components/camel-salesforce/camel-salesforce-c...           M
# 422919  connectors/examples/salesforce-upsert-contact-...           A
# 489334  components/camel-thrift/src/test/java/org/apac...           A
#
#        snippet_length_range
# 250262                0-100
# 240268                0-100
# 240266                0-100
# 240261                0-100
# 445351                0-100
# ...                     ...
# 518098           1000-50000
# 592150           1000-50000
# 412710           1000-50000
# 422919           1000-50000
# 489334           1000-50000
#
# [723430 rows x 8 columns]
